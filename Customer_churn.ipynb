# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammadsodiq0011/Muhammadsodiq0011/blob/main/Customer_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

from sklearn.pipeline import Pipeline
from sklearn import metrics

# %% [markdown]
# # Data Science and Artificial Intelligence
#
# ## 5-MODULE. Machine Learning.
#
# # Classification
#
# ### Determining customer churn
#
# One of the most common problems in business. Determining the client’s mood.
#
# If a business owner can predict that a customer will not return, will not reuse a product or service, he or she may try to change his or her mind in order to retain the customer.
#
# In this practice, we predict whether a customer will stay by analyzing online store customer data.

# %%
url="https://github.com/anvarnarz/praktikum_datasets/blob/main/E-Commerce-Dataset.xlsx?raw=true"

df = pd.read_excel(url, sheet_name="E Comm")

df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.shape
# Out:
# (5630, 20)

# %%
description = pd.read_excel(url, sheet_name="Data Dict", header=1, usecols=[1,2,3])
description
# Out:
#       Data                     Variable  \
# 0   E Comm                   CustomerID
# 1   E Comm                        Churn
# 2   E Comm                       Tenure
# 3   E Comm         PreferredLoginDevice
# 4   E Comm                     CityTier
# 5   E Comm              WarehouseToHome
# 6   E Comm         PreferredPaymentMode
# 7   E Comm                       Gender
# 8   E Comm               HourSpendOnApp
# 9   E Comm     NumberOfDeviceRegistered
# 10  E Comm             PreferedOrderCat
# 11  E Comm            SatisfactionScore
# 12  E Comm                MaritalStatus
# 13  E Comm              NumberOfAddress
# 14  E Comm                     Complain
# 15  E Comm  OrderAmountHikeFromlastYear
# 16  E Comm                   CouponUsed
# 17  E Comm                   OrderCount
# 18  E Comm            DaySinceLastOrder
# 19  E Comm               CashbackAmount
#
#                                           Discerption
# 0                                  Unique customer ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df['Churn'].value_counts()/len(df)*100
# Out:
# 0    83.161634
# 1    16.838366
# Name: Churn, dtype: float64

# %% [markdown]
# - 4682 customers repurchased (remaining)
# - 948 customers left

# %%
churn_rate = df['Churn'].value_counts()/len(df)*100

# %%
plt.figure(figsize=(5,5))
plt.pie(churn_rate, labels=['Loyal','Left'])
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))

# Tenure
sns.histplot(x="Tenure", data=df, ax=axes[0])
axes[0].set_title("Client duration")

#OrderCount
sns.histplot(x="OrderCount", data=df, ax=axes[1])
axes[1].set_title("Number of customer orders")

# Cashback
sns.histplot(x="CashbackAmount", data=df, ax=axes[2])
axes[2].set_title("Amount of cashback")

plt.show()

# %% [markdown]
# Analyzing the category columns

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))

sns.countplot(x='Gender', hue='Churn', palette='viridis', data=df, ax=axes[0])
axes[0].set_title("Gender of remaining & returning customers")

sns.countplot(x='MaritalStatus', hue='Churn', palette='viridis', data=df, ax=axes[1])
axes[1].set_title("Marital status of remaining & returning customers")

sns.countplot(x='Complain', hue='Churn', palette='viridis', data=df, ax=axes[2])
axes[1].set_title("Complaints from remaining & returning customers")
plt.show()

# %%
df.corrwith(df['Churn']).abs().sort_values(ascending=False)
# Out:
# Churn                          1.000000
# Tenure                         0.349408
# Complain                       0.250188
# DaySinceLastOrder              0.160757
# CashbackAmount                 0.154118
# NumberOfDeviceRegistered       0.107939
# SatisfactionScore              0.105481
# CityTier                       0.084703
# WarehouseToHome                0.076630
# NumberOfAddress                0.043931
# OrderCount                     0.028697
# CustomerID                     0.019083
# HourSpendOnApp                 0.018675
# OrderAmountHikeFromlastYear    0.010058
# CouponUsed                     0.008264
# dtype: float64

# %% [markdown]
# Data processing

# %%
#the number of non-existent values
print(f"Number of non-existent values: {df.isnull().sum().sum()}")
missing_rows = df[df.isnull().any(axis=1)].shape[0]
print(f"Number of rows not available: {missing_rows}")
print(f"Non-existent rows%: {np.round(missing_rows/len(df)*100)}%")
# Out:
# Number of non-existent values: 1856
# Number of rows not available: 1856
# Non-existent rows%: 33.0%

# %% [markdown]
# 33% too much. But do we use all the columns?
#
# Let's sort out the columns with high correlation and some categorical (text) columns (you have to decide which columns to sort. We are just giving an example)

# %%
data = df[['Churn','Tenure','Complain','DaySinceLastOrder','CashbackAmount','MaritalStatus','Gender']]

# %%
print(f"Number of non-existent values: {data.isnull().sum().sum()}")

missing_rows = data[data.isnull().any(axis=1)].shape[0]
print(f"Number of rows not available: {missing_rows}")
#row ratio
print(f"Non-existent rows %: {np.round(missing_rows/len(data)*100)}%")
# Out:
# Number of non-existent values: 571
# Number of rows not available: 571
# Non-existent rows %: 10.0%

# %% [markdown]
# 10% row value is not available. How you behave with these values is up to you.
#
# And we’re dropping those lines for now.

# %%
data = data.dropna()
data.shape
# Out:
# (5059, 7)

# %%
data['Churn'].value_counts()/len(data)
# Out:
# 0    0.839296
# 1    0.160704
# Name: Churn, dtype: float64

# %% [markdown]
# Preparing for ML

# %%
# We convert text columns to numbers
encoded = pd.get_dummies(data)
encoded.head()
# Out:
#    Churn  Tenure  Complain  DaySinceLastOrder  CashbackAmount  \
# 0      1     4.0         1                5.0          159.93
# 3      1     0.0         0                3.0          134.07
# 4      1     0.0         0                3.0          129.60
# 5      1     0.0         1                7.0          139.19
# 8      1    13.0         1                2.0          126.83
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                       0                      0                     1
# 3                       0                      0                     1
# 4                       0                      0                     1
# 5                       0                      0                     1
# 8                       1                      0                     0
#
#    Gender_Female  Gender_Male
# 0              1            0
# 3              0            1
# 4              0            1
# 5              1            0
# ...

# %%
X = encoded.drop("Churn", axis=1)
y = encoded['Churn']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# Machine Learning
#
# Logistic Regression

# %%
# creating a model (training)
LR_model = LogisticRegression()
LR_model.fit(X_train, y_train)

# Rating model
y_pred = LR_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy:", metrics.accuracy_score(y_test,y_pred))

## confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True,fmt="g")
plt.show()

## ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       849
#            1       0.75      0.38      0.50       163
#
#     accuracy                           0.88      1012
#    macro avg       0.82      0.68      0.72      1012
# weighted avg       0.87      0.88      0.86      1012
#
# Model accuracy: 0.8794466403162056

# %% [markdown]
# ### Support Vector Machines

# %%
# Modelni yaratamiz (training)
svm_model = SVC()
svm_model.fit(X_train, y_train)

# Modelni baholaymiz
y_pred = svm_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy:", metrics.accuracy_score(y_test,y_pred))

## confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True,fmt="g")
plt.show()

## ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       849
#            1       0.67      0.31      0.42       163
#
#     accuracy                           0.86      1012
#    macro avg       0.77      0.64      0.67      1012
# weighted avg       0.85      0.86      0.84      1012
#
# Model accuracy: 0.8636363636363636

# %% [markdown]
# ### Decision Tree

# %%
# Creating a model (training)
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)

# Rating a model
y_pred = tree_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy:", metrics.accuracy_score(y_test,y_pred))

## confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True,fmt="g")
plt.show()

## ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       849
#            1       0.84      0.90      0.87       163
#
#     accuracy                           0.96      1012
#    macro avg       0.91      0.93      0.92      1012
# weighted avg       0.96      0.96      0.96      1012
#
# Model accuracy: 0.9565217391304348

# %%
cols = encoded.drop('Churn', axis=1).columns

plt.figure(figsize=(30,20))
plot_tree(tree_model, feature_names=cols, filled=True)
plt.show()

# %% [markdown]
# ### Random Forest

# %%
# Creating a model
RF_model = RandomForestClassifier(n_estimators=9)
RF_model.fit(X_train, y_train)

# Rating a model
y_pred = RF_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy:", metrics.accuracy_score(y_test,y_pred))

## confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True,fmt="g")
plt.show()

## ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       849
#            1       0.84      0.81      0.82       163
#
#     accuracy                           0.94      1012
#    macro avg       0.90      0.89      0.89      1012
# weighted avg       0.94      0.94      0.94      1012
#
# Model accuracy: 0.9436758893280632

# %% [markdown]
# ### XGBoost

# %%
# Creating a model (training)
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)

# rating a model
y_pred = xgb_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy:", metrics.accuracy_score(y_test,y_pred))

## confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True,fmt="g")
plt.show()

## ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       849
#            1       0.70      0.52      0.59       163
#
#     accuracy                           0.89      1012
#    macro avg       0.81      0.74      0.76      1012
# weighted avg       0.88      0.89      0.88      1012
#
# Model accuracy: 0.8863636363636364
